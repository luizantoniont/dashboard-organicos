# %%
import pandas as pd

# %%
path = '../data/output/cadastro_produtores.csv'
df = pd.read_csv(path, encoding='utf-8')

df
# Out:
#       tipo_de_entidade                                           entidade  \
# 0                  OCS                                   AMIGOS ORGÂNICOS
# 1                  OCS                                   AMIGOS ORGÂNICOS
# 2                  OCS                                   AMIGOS ORGÂNICOS
# 3                  OCS                                   AMIGOS ORGÂNICOS
# 4                  OCS                                   AMIGOS ORGÂNICOS
# ...                ...                                                ...
# 25229             OPAC  ASSOCIAÇÃO DE CERTIFICAÇÃO ORGÂNICA PARTICIPAT...
# 25230             OPAC  ASSOCIAÇÃO DE CERTIFICAÇÃO ORGÂNICA PARTICIPAT...
# 25231             OPAC  ASSOCIAÇÃO DE CERTIFICAÇÃO ORGÂNICA PARTICIPAT...
# 25232             OPAC  ASSOCIAÇÃO DE CERTIFICAÇÃO ORGÂNICA PARTICIPAT...
# 25233             OPAC  ASSOCIAÇÃO DE CERTIFICAÇÃO ORGÂNICA PARTICIPAT...
#
#          pais  uf       cidade situação  cnpf/cnpj/nif  \
# 0      BRASIL  RN     EXTREMOZ    ATIVO  ***053.874***
# 1      BRASIL  RN        NATAL    ATIVO  ***695.504***
# 2      BRASIL  RN        NATAL    ATIVO  ***101.644***
# 3      BRASIL  RN        NATAL    ATIVO  ***244.844***
# 4      BRASIL  RN        NATAL    ATIVO  ***048.904***
# ...       ...  ..          ...      ...            ...
# 25229  BRASIL  RN  SANTA MARIA    ATIVO  ***640.544***
# 25230  BRASIL  RN    RIACHUELO    ATIVO  ***868.414***
# 25231  BRASIL  RN         ASSU    ATIVO  ***423.334***
# 25232  BRASIL  RN     CARAÚBAS    ATIVO  ***432.634***
# 25233  BRASIL  RN     CARAÚBAS    ATIVO  ***842.364***
#
#                        nome_do_produtor                     escopo  \
# 0       ADRIANO FERNANDES DO NASCIMENTO                        NaN
# 1                  AILTON DO NASCIMENTO                        NaN
# 2        ANA MARIA DO NASCIMENTO CÂMARA                        NaN
# 3      FERNANDO LUIZ SILVESTRE FERREIRA                        NaN
# 4        MARIA DAS GRAÇAS DO NASCIMENTO                        NaN
# ...                                 ...                        ...
# 25229                   RUBENS GRACIANO  PRODUÇÃO PRIMÁRIA VEGETAL
# 25230               SALATIEL JOSÉ CLARO  PRODUÇÃO PRIMÁRIA VEGETAL
# 25231  SAMARA REJANE DOS SANTOS ALENCAR  PRODUÇÃO PRIMÁRIA VEGETAL
# 25232                   SIDICLEIA ALVES  PRODUÇÃO PRIMÁRIA VEGETAL
# 25233     SUEILHA MARCOLINO DE OLIVEIRA  PRODUÇÃO PRIMÁRIA VEGETAL
#
#                                               atividades           contato
# 0                                                    NaN                ;
# 1                                                    NaN                ;
# 2                                                    NaN                ;
# 3                                                    NaN                ;
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 25229     FEIJÃO, MACAXEIRA, JERIMUM, MELANCIA, ALGODÃO.      84 9955-5969
# 25230                  MILHO, FEIJÃO, ALGODÃO E GERGELIM  84 - 99837- 4311
# 25231  CAJU, MANGA, GOIABA, PINHA, ACEROLA, GRAVIOLA,...      84 9619-2378
# 25232  ALGODÃO, FEIJÃO, MILHO, GERGELIM, AZEITONA, CO...      84-9205-4052
# 25233                  ALGODÃO, MILHO, GERGELIM, FEIJÃO.   84- 99663- 8084
#
# [25234 rows x 11 columns]

# %%
# %pip install -U ydata-profiling
# %pip install ipywidgets
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.14.0)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (3.9.1)
# Requirement already satisfied: pydantic>=2 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.7.4)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\luizz\appdata\roaming\python\python311\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: puremagic in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.28)
# Requirement already satisfied: six>=1.5 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.6-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipywidgets) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.14 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: colorama in c:\users\luizz\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\luizz\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\luizz\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\luizz\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\luizz\appdata\local\programs\python\python311\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.6-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl (213 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 13.7 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.6 jupyterlab_widgets-3.0.14 widgetsnbextension-4.0.14
# Note: you may need to restart the kernel to use updated packages.

# %%
import ydata_profiling
from pandas_profiling import ProfileReport

profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
profile.to_file("your_report.html")
